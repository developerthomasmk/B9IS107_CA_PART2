# %% [markdown]
# <a href="https://colab.research.google.com/github/developerthomasmk/B9IS107_CA_PART2/blob/main/B9IS107_CA_PART2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set visual style
sns.set(style="whitegrid", palette="pastel")

# Load your dataset
file_path = '/content/Loan.xlsx'  # Update path as needed
loan_data = pd.ExcelFile(file_path)
loan_df = loan_data.parse('Loan')

# 1. Distribution of RiskScore
plt.figure(figsize=(10, 6))
sns.histplot(loan_df['RiskScore'], kde=True, bins=20, color='blue')
plt.title('Distribution of RiskScore', fontsize=16)
plt.xlabel('RiskScore', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-5beaeb07dd93> in <cell line: 24>()
#      22 # 2. Correlation Heatmap
#      23 plt.figure(figsize=(12, 8))
# ---> 24 correlation_matrix = loan_df.corr()
#      25 sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
#      26 plt.title('Correlation Heatmap', fontsize=16)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# ...

# %%
# 2. Correlation Heatmap
plt.figure(figsize=(12, 8))
correlation_matrix = loan_df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap', fontsize=16)
plt.show()

# %%
# 3. Scatter Plots of Key Predictors vs RiskScore
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Predictor 1: CreditScore
sns.scatterplot(ax=axes[0], x='CreditScore', y='RiskScore', data=loan_df, color='green')
axes[0].set_title('CreditScore vs RiskScore')

# Predictor 2: AnnualIncome
sns.scatterplot(ax=axes[1], x='AnnualIncome', y='RiskScore', data=loan_df, color='purple')
axes[1].set_title('AnnualIncome vs RiskScore')

# Predictor 3: TotalDebtToIncomeRatio
sns.scatterplot(ax=axes[2], x='TotalDebtToIncomeRatio', y='RiskScore', data=loan_df, color='red')
axes[2].set_title('TotalDebtToIncomeRatio vs RiskScore')

plt.tight_layout()
plt.show()

# %%
# 4. Bar Plot: RiskScore by EducationLevel
plt.figure(figsize=(10, 6))
sns.barplot(hue='EducationLevel', y='RiskScore', data=loan_df, errorbar=None, palette='pastel')
plt.title('RiskScore by EducationLevel', fontsize=16)
plt.xlabel('Education Level', fontsize=12)
plt.ylabel('Average RiskScore', fontsize=12)
plt.xticks(rotation=45)
plt.show()
